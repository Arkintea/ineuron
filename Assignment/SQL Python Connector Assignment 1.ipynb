# %%
import mysql.connector as conn
mydb = conn.connect(host='localhost', user='root', passwd='1qaz@WSX')
cursor =mydb.cursor()
cursor.execute('show databases')
cursor.fetchall()
# Out:
# [('cardataset',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('testsudhineuron',),
#  ('world',)]

# %% [markdown]
# <b>create a database called as cardataset</b>

# %%
cursor.execute('create database cardatabase')
cursor.execute('use cardatabase')
cursor.fetchall()
# Out:
# []

# %% [markdown]
# <b>create a table called as car with a column name given in dataset description</b>

# %%
cursor.execute('create table cardatabase.car(col1 VARCHAR(30), col2 VARCHAR(30), col3 VARCHAR(30), col4 VARCHAR(30), col5 VARCHAR(30), col6 VARCHAR(30), col7 VARCHAR(30))')
cursor.execute('show tables')
cursor.fetchall()
# Out:
# [('car',)]

# %% [markdown]
# <b>Dump all the data into car table<b/>

# %%
## Data Preview
import csv
with open('car.data', 'r') as f:
    car_data = csv.reader(f, delimiter = '\n')
    for i in car_data:
        row_data = i[0].split(',')
        print(row_data)
# Out:
# ['vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc']
# ['vhigh', 'vhigh', '2', '2', 'small', 'med', 'unacc']
# ['vhigh', 'vhigh', '2', '2', 'small', 'high', 'unacc']
# ['vhigh', 'vhigh', '2', '2', 'med', 'low', 'unacc']
# ['vhigh', 'vhigh', '2', '2', 'med', 'med', 'unacc']
# ['vhigh', 'vhigh', '2', '2', 'med', 'high', 'unacc']
# ['vhigh', 'vhigh', '2', '2', 'big', 'low', 'unacc']
# ['vhigh', 'vhigh', '2', '2', 'big', 'med', 'unacc']
# ['vhigh', 'vhigh', '2', '2', 'big', 'high', 'unacc']
# ['vhigh', 'vhigh', '2', '4', 'small', 'low', 'unacc']
# ['vhigh', 'vhigh', '2', '4', 'small', 'med', 'unacc']
# ['vhigh', 'vhigh', '2', '4', 'small', 'high', 'unacc']
# ['vhigh', 'vhigh', '2', '4', 'med', 'low', 'unacc']
# ['vhigh', 'vhigh', '2', '4', 'med', 'med', 'unacc']
# ['vhigh', 'vhigh', '2', '4', 'med', 'high', 'unacc']
# ['vhigh', 'vhigh', '2', '4', 'big', 'low', 'unacc']
# ['vhigh', 'vhigh', '2', '4', 'big', 'med', 'unacc']
# ['vhigh', 'vhigh', '2', '4', 'big', 'high', 'unacc']
# ...

# %%
with open('car.data', 'r') as f:
    car_data = csv.reader(f, delimiter = '\n')
    for i in car_data:
        row_data = i[0].split(',')
        #query = "INSERT INTO cardatabase.car VALUES({})".format(str(i[0]))
        cursor.execute("INSERT INTO cardatabase.car VALUES('{}','{}','{}','{}','{}','{}','{}')".format(str(row_data[0]), str(row_data[1]), str(row_data[2]), str(row_data[3]), str(row_data[4]), str(row_data[5]), str(row_data[6])))
mydb.commit()

# %%
cursor.execute('select * from cardatabase.car')
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'med', 'unacc'),
# ...

# %%
cursor.execute('select col1, count(*) from cardatabase.car group by col1')
cursor.fetchall()
# Out:
# [('vhigh', 864), ('high', 864), ('med', 864), ('low', 864)]

# %%
cursor.execute('select * from cardatabase.car where col3 = "4"')
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '4', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '4', '4', 'big', 'med', 'unacc'),
# ...

# %% [markdown]
# <b>update a col 3 value with 8 whereever you have value equal to 2</b>

# %%
cursor.execute('update cardatabase.car set col3 = "8" where col3 = "2"')
cursor.fetchall()
# Out:
# []

# %% [markdown]
# <b>drop table</b>

# %%
cursor.execute('drop table cardatabase.car')
cursor.fetchall()
# Out:
# []

# %%
cursor.execute('show tables')
cursor.fetchall()
# Out:
# []

# %% [markdown]
# <b>drop data base</b>

# %%
cursor.execute('show databases')
cursor.fetchall()
# Out:
# [('cardatabase',),
#  ('cardataset',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('testsudhineuron',),
#  ('world',)]

# %%
cursor.execute('drop database cardatabase')
cursor.fetchall()
# Out:
# []

# %%
cursor.execute('show databases')
cursor.fetchall()
# Out:
# [('cardataset',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('testsudhineuron',),
#  ('world',)]
